# %%
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import curve_fit # Az illesztéshez használt függvény
import math

# %%
adat = []
with open('hullam_.dat') as f:
    for l in f.readlines():
        o = l.split()
        if len(o) != 12:
            continue
        adat.append(list(map(lambda x: float(x), o)))
        
adat = np.array(adat)

# %%
np.argwhere(adat[:, 0] == adat[:,0].min())
# Out:
# array([[0]])

# %%
adat[:,0].min()
# Out:
# 7995010.0

# %%
adat.shape
# Out:
# (1920, 12)

# %%
hullam=adat

# %%
plt.figure(figsize=(20,6))
t=hullam[:,0]
T1=hullam[:,1]
plt.plot(t,T1,'.')

# %%
len(hullam[:,0])
# Out:
# 334

# %%
len(hullam[:,1])
# Out:
# 334
